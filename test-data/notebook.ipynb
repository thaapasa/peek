# %% [markdown]
# # Sales analysis
#
# A short notebook: load data, plot it, hit an error.

# %%
import numpy as np
data = np.array([3, 1, 4, 1, 5, 9, 2, 6])
print('loaded', data.size, 'points')
data.mean()
# Out:
# loaded 8 points
# np.float64(3.875)

# %%
import matplotlib.pyplot as plt
plt.plot(data)
plt.title('values')

# %%
1 / 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 1 / 0
# ZeroDivisionError: division by zero

# %% [raw]
# raw cell, passed through verbatim
